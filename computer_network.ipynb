# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv('C:/Users/patel/OneDrive/Documents/internship/intership_datascince-main/CN_Trafic.csv')

# %%
df.head()
# Out:
#          date  l_ipn  r_asn  f
# 0  2006-07-01      0    701  1
# 1  2006-07-01      0    714  1
# 2  2006-07-01      0   1239  1
# 3  2006-07-01      0   1680  1
# 4  2006-07-01      0   2514  1

# %%
df.describe()
# Out:
#               l_ipn         r_asn              f
# count  20803.000000  20803.000000   20803.000000
# mean       4.228236  12138.320338      93.914243
# std        3.278183   9766.324252    5764.995269
# min        0.000000      3.000000       1.000000
# 25%        1.000000   4323.000000       1.000000
# 50%        4.000000   8764.000000       2.000000
# 75%        7.000000  17676.000000       8.000000
# max        9.000000  40092.000000  784234.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20803 entries, 0 to 20802
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    20803 non-null  object
#  1   l_ipn   20803 non-null  int64
#  2   r_asn   20803 non-null  int64
#  3   f       20803 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 650.2+ KB

# %%
df.isnull().sum()
# Out:
# date     0
# l_ipn    0
# r_asn    0
# f        0
# dtype: int64

# %%
df.head(15)
# Out:
#          date  l_ipn   r_asn     f  yday  wday
# 0  2006-07-01      0  436704   106   182     5
# 1  2006-07-01      1  182194   640   182     5
# 2  2006-07-01      2  212966  1677   182     5
# 3  2006-07-01      3   96376    22   182     5
# 4  2006-07-01      4  120507   184   182     5
# 5  2006-07-01      5  125647    44   182     5
# 6  2006-07-01      6  117227    63   182     5
# 7  2006-07-01      7  479524   411   182     5
# 8  2006-07-01      8  339609   448   182     5
# 9  2006-07-01      9  407669  1463   182     5
# 10 2006-07-02      0  460025   920   183     6
# 11 2006-07-02      1  447528  2661   183     6
# 12 2006-07-02      2   96897  2036   183     6
# 13 2006-07-02      3   69276    30   183     6
# 14 2006-07-02      4  132407   941   183     6

# %%
numerical_features = df.select_dtypes(include=[np.number]).columns.tolist()

for feature in numerical_features:
    plt.figure(figsize=(10, 5))
    sns.histplot(df[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(df[numerical_features])
plt.title('Pairplot of Numerical Features')
plt.show()
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
for feature in numerical_features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(data=df, y=feature)
    plt.title(f'Boxplot of {feature}')
    plt.ylabel(feature)
    plt.show()

# %%
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])
    df.set_index('date', inplace=True)
    for num_feature in numerical_features:
        plt.figure(figsize=(12, 6))
        df[num_feature].resample('M').mean().plot()
        plt.title(f'Monthly Average of {num_feature}')
        plt.xlabel('Date')
        plt.ylabel(num_feature)
        plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_9336\1593053494.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df[num_feature].resample('M').mean().plot()
# C:\Users\patel\AppData\Local\Temp\ipykernel_9336\1593053494.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df[num_feature].resample('M').mean().plot()
# C:\Users\patel\AppData\Local\Temp\ipykernel_9336\1593053494.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df[num_feature].resample('M').mean().plot()
# C:\Users\patel\AppData\Local\Temp\ipykernel_9336\1593053494.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df[num_feature].resample('M').mean().plot()
# ...

# %%
for feature in numerical_features:
    plt.figure(figsize=(10, 5))
    sns.violinplot(data=df, y=feature)
    plt.title(f'Violin Plot of {feature}')
    plt.ylabel(feature)
    plt.show()

# %%
for feature in numerical_features:
    if df[feature].min() > 0: 
        plt.figure(figsize=(10, 5))
        sns.histplot(np.log(df[feature]), kde=True, bins=30)
        plt.title(f'Log Transformed Distribution of {feature}')
        plt.xlabel(f'Log of {feature}')
        plt.ylabel('Frequency')
        plt.show()
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
selected_features = numerical_features[:2] 
sns.pairplot(df[selected_features])
plt.title('Pairplot of Selected Numerical Features')
plt.show()
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
if 'l_ipn' in df.columns:
    decomposition = sm.tsa.seasonal_decompose(df['l_ipn'], model='additive', period=30)
    fig = decomposition.plot()
    fig.set_size_inches(12, 8)
    plt.suptitle('Seasonal Decomposition of l_ipn', fontsize=16)
    plt.show()

# %%
plt.figure(figsize=(12, 6))
df['f'].resample('M').mean().plot()
plt.title('Monthly Average of Flows (f)')
plt.xlabel('Date')
plt.ylabel('Flows (f)')
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_9336\3946322570.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df['f'].resample('M').mean().plot()

# %%
log_f = np.log(df['f'] + 1) 
plt.figure(figsize=(10, 5))
sns.histplot(log_f, kde=True, bins=30)
plt.title('Log-transformed Distribution of Flows (f)')
plt.xlabel('Log(Flows)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
monthly_flows = df['f'].resample('M').sum()
plt.figure(figsize=(12, 6))
monthly_flows.plot(kind='bar', color='skyblue')
plt.title('Number of Flow Counts per Month')
plt.xlabel('Month')
plt.ylabel('Flow Counts')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_9336\241701195.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_flows = df['f'].resample('M').sum()

# %% [markdown]
# ### OBSERVATION :
# ##### from this we can understand that the values of I_ipn and r_asn are increasing monthly.also that in the r_asn there are outliers present at the upper end that means few amount of large numbers are present and other are distributed properly.I used log transformation technique which we use to reduce the skewness of the feature. there is not much correlation between that features thats what we understand from the heat map. We cannot remove the outliers as we don't know if it is useful or will improve the model we can say after we try. But from current analysis we can say that the flow which is the count of device connected is increasing monthly.
